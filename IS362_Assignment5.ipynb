# %% [markdown]
# # IS 362 – Week 5 Assignment
# ## Your task in this week’s assignment is to answer three questions:
# 1. What is the northernmost airport in the United States?
# 2. What is the easternmost airport in the United States?
# 3. On February 12th, 2013, which New York area airport had the windiest weather?
#
# Use the information in the .CSV files found at https://github.com/hadley/nycflights13/tree/master/data-raw for your source data Write your code using Python and pandas, and deliver it in a Jupyter notebook. You should post your notebook in a GitHub repository, and send me a link to the notebook.

# %% [markdown]
# First we import the `airports.csv` file into a Dataframe

# %%
import pandas as pd

# %%
airports = pd.read_csv('https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/airports.csv')
airports
# Out:
#       faa                                  name        lat         lon   alt  \
# 0     04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1     06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2     06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3     06N                       Randall Airport  41.431912  -74.391561   523
# 4     09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5     0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6     0G6               Williams County Airport  41.467306  -84.506778   730
# 7     0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8     0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9     0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10    0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %% [markdown]
# now that we have our Dataframe we should serch it for NaN values

# %%
airports.isnull().sum()
# Out:
# faa      0
# name     0
# lat      0
# lon      0
# alt      0
# tz       0
# dst      0
# tzone    3
# dtype: int64

# %% [markdown]
# Luckily we only have 3 tzones  values that are`NaN`

# %% [markdown]
# ***
# Lets pull up those 3 rows to decide our aproch better.

# %%
airports[airports.tzone.isnull()]
# Out:
#       faa                                  name        lat         lon  alt  \
# 417   EEN               Dillant Hopkins Airport  72.270833   42.898333  149
# 815   LRO  Mount Pleasant Regional-Faison Field  32.538700  -79.469700   12
# 1434  YAK                               Yakutat  59.301200 -139.393700   33
#
#       tz dst tzone
# 417   -5   A   NaN
# 815   -5   A   NaN
# 1434  -9   A   NaN

# %% [markdown]
# here are the 3 entries that contain `NaN` values

# %% [markdown]
# ***
# In order to make changed with out changing our original data, we will make a copy of the `airports` Dataframe. We will call it `airportscopy`

# %% [markdown]
#  Now we will change the `NaN` values in our `airportscopy`, and change those `NaN` values to `'UNKNOWN'`

# %%
airportscopy = airports.copy()
airportscopy['tzone'].fillna(value='UNKNOWN', inplace=True)
airportscopy
# Out:
#       faa                                  name        lat         lon   alt  \
# 0     04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1     06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2     06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3     06N                       Randall Airport  41.431912  -74.391561   523
# 4     09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5     0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6     0G6               Williams County Airport  41.467306  -84.506778   730
# 7     0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8     0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9     0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10    0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %% [markdown]
# now since all the values in tzones are strings we can serch tzones  for all airports tzones that are in 'America'.
# ***

# %% [markdown]
# we will create a new dataframe `us_airports` to represent just results that have a tzone that contains the word `'America'` in it.

# %%
us_airports = airportscopy[airportscopy['tzone'].str.contains("America")]
us_airports
# Out:
#       faa                                  name        lat         lon   alt  \
# 0     04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1     06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2     06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3     06N                       Randall Airport  41.431912  -74.391561   523
# 4     09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5     0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6     0G6               Williams County Airport  41.467306  -84.506778   730
# 7     0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8     0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9     0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10    0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %% [markdown]
# Lets compare our results and see how many rows were removed

# %%
rows_removed = len(airports) - len(us_airports)
rows_removed
# Out:
# 23

# %% [markdown]
# Since we lost alot of rows we should check our value counts of `tzone` in our `airportscopy` Dataframe to se exsactly what `tzones` were removed when we created `us_airports`.

# %%
airportscopy['tzone'].value_counts(dropna=False)
# Out:
# America/New_York       519
# America/Chicago        342
# America/Anchorage      239
# America/Los_Angeles    176
# America/Denver         119
# America/Phoenix         38
# Pacific/Honolulu        18
# UNKNOWN                  3
# America/Vancouver        2
# Asia/Chongqing           2
# Name: tzone, dtype: int64

# %% [markdown]
# For the sake of this assiment, we will only keep the data we can confirm is in America based on the data we are given.

# %% [markdown]
# We can see we have tzone Asia/Chongqing that we know is not in the us so tthose can be removed

# %% [markdown]
# we also see we have Pacific/Honolulu now this dose not say america even though hawaii is in the pacific and is in the us , we will still remove it becuse not all airports in the pacific are in america and we are only looking up northern most and eastern most airports so we can remove the Pacific/Honolulu results as they are west of the US

# %% [markdown]
# Also we have the tzone we created that were NaN and are now 'UNKNOWN'

# %% [markdown]
# so if we compare this to list to what is in `us_airports`

# %%
us_airports['tzone'].value_counts(dropna=False)
# Out:
# America/New_York       519
# America/Chicago        342
# America/Anchorage      239
# America/Los_Angeles    176
# America/Denver         119
# America/Phoenix         38
# America/Vancouver        2
# Name: tzone, dtype: int64

# %% [markdown]
# I am comfortable using this to answere our questions 1 & 2

# %% [markdown]
# For question **1. What is the northernmost airport in the United States?** in order to find our northern most airport we will look for the top 5 rsults with the largest `'lat'` results in `us_airports` we will cal this new result `northern_most_airports`

# %%
northern_most_airports = us_airports.sort_values(by = 'lat', ascending = False).head()
northern_most_airports
# Out:
#       faa                                        name        lat         lon  \
# 230   BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 110   AIN                          Wainwright Airport  70.638056 -159.994722
# 708   K03                               Wainwright As  70.613378 -159.860350
# 152   ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
# 1363  UUK                        Ugnu-Kuparuk Airport  70.330833 -149.597500
#
#       alt  tz dst              tzone
# 230    44  -9   A  America/Anchorage
# 110    41  -9   A  America/Anchorage
# 708    35  -9   A  America/Anchorage
# 152    96  -9   A  America/Anchorage
# 1363   67  -9   A  America/Anchorage

# %% [markdown]
# According to a quick search or our top result [Google Map Search](https://www.google.com/maps/place/Wiley+Post-Will+Rogers+Memorial+Airport/@63.083625,-132.8824806,4z/data=!4m5!3m4!1s0x0:0x936de8c8fd2d094b!8m2!3d71.2874212!4d-156.7802701) search or our top result `Wiley Post Will Rogers Mem` we can see that it is at the very top of Alaska the northern most state in America so this seems to be true.
# from IPython.core.display import display, HTML
# ![pic](https://photos.wikimapia.org/p/00/01/29/78/51_big.jpg)

# %% [markdown]
# ## So, the Answer to question *1. What is the northernmost airport in the United States?* is:
# ## **Wiley Post Will Rogers Mem**
# ***

# %% [markdown]
# For question **2. What is the easternmost airport in the United States?** we just need to do a little modification to our `northern_most_airports` search. we will swap out `lat` for `lon`, meaning longitued, and rename our new result `eastern_most_airports` and this should give us our answere.

# %%
eastern_most_airports = us_airports.sort_values(by = 'lon', ascending = False).head()
eastern_most_airports
# Out:
#       faa                                 name        lat         lon  alt  \
# 1290  SYA                         Eareckson As  52.712275  174.113620   98
# 444   EPM           Eastport Municipal Airport  44.910111  -67.012694   45
# 624   HUL                         Houlton Intl  46.123083  -67.792056  489
# 259   CAR                         Caribou Muni  46.871500  -68.017917  626
# 1101  PQI  Northern Maine Rgnl At Presque Isle  46.688958  -68.044797  534
#
#       tz dst              tzone
# 1290  -9   A  America/Anchorage
# 444   -5   A   America/New_York
# 624   -5   A   America/New_York
# 259   -5   A   America/New_York
# 1101  -5   A   America/New_York

# %% [markdown]
# Our top result is `Eareckson As`. The problem I see with this is according to the `tzone` in the dataframe, this airport is in the Alaska time zone, and alaska is located west of the United states. A quick internet serch and  [Wikipedia](https://en.wikipedia.org/wiki/Eareckson_Air_Station) confirms this.
# So I must assume the `lon` in this entry for `Eareckson As` is incorect. We will move on to the next row result which is `Eastport Municipal Airport`.

# %% [markdown]
# Once we do a quick [Google Maps Serch](https://www.google.com/maps/place/Eastport+Municipal+Airport-EPM/@40.1860431,-101.0731964,4.96z/data=!4m5!3m4!1s0x0:0xe8e7c4805bb5f1e8!8m2!3d44.9099796!4d-67.0119367) we see that `Eastport Municipal Airport` is in Main which is so far east in the US that it is near the border of Canada.
# ![Eastport Runway pic](https://www.funplacestofly.com/photos/airportlowe85242.jpg)

# %% [markdown]
# ## So, the Answer to question *2. What is the easternmost airport in the United States?* is:
# ## **Eastport Municipal Airport**
# ***

# %% [markdown]
# For question **3. On February 12th, 2013, which New York area airport had the windiest weather?** we will switch csv files and use the `weather.csv` file in the git hub repository. we will import this csv file into a dataframe named `weather`.

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/weather.csv')
weather
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0        EWR  2013      1    1     1  39.02  26.06  59.37     270.0
# 1        EWR  2013      1    1     2  39.02  26.96  61.63     250.0
# 2        EWR  2013      1    1     3  39.02  28.04  64.43     240.0
# 3        EWR  2013      1    1     4  39.92  28.04  62.21     250.0
# 4        EWR  2013      1    1     5  39.02  28.04  64.43     260.0
# 5        EWR  2013      1    1     6  37.94  28.04  67.21     240.0
# 6        EWR  2013      1    1     7  39.02  28.04  64.43     240.0
# 7        EWR  2013      1    1     8  39.92  28.04  62.21     250.0
# 8        EWR  2013      1    1     9  39.92  28.04  62.21     260.0
# 9        EWR  2013      1    1    10  41.00  28.04  59.65     260.0
# 10       EWR  2013      1    1    11  41.00  26.96  57.06     260.0
# 11       EWR  2013      1    1    13  39.20  28.40  69.67     330.0
# 12       EWR  2013      1    1    14  39.02  24.08  54.68     280.0
# ...

# %% [markdown]
# ***
# Now that we have all the weather in a dataframe,  we can filter it to only return us the results from february 12th, 2013 we will name this `feb_12_2013_weather`.

# %%
feb_12_2013_weather = weather[(weather.year == 2013) & (weather.day == 12) & (weather.month == 2)]
feb_12_2013_weather
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 1006     EWR  2013      2   12     0  39.92  39.02  96.55     240.0
# 1007     EWR  2013      2   12     1  39.92  37.94  92.56     250.0
# 1008     EWR  2013      2   12     2  39.92  28.04  62.21     270.0
# 1009     EWR  2013      2   12     3  39.02  26.96  61.63     260.0
# 1010     EWR  2013      2   12     4  39.02  26.96  64.29     280.0
# 1011     EWR  2013      2   12     5  39.92  26.96  60.29     270.0
# 1012     EWR  2013      2   12     6  39.02  26.96  61.63     270.0
# 1013     EWR  2013      2   12     7  39.92  24.98  54.81     260.0
# 1014     EWR  2013      2   12     8  42.08  26.60  60.29     250.0
# 1015     EWR  2013      2   12     9  41.90  24.98  50.77     290.0
# 1016     EWR  2013      2   12    10  42.08  26.06  52.73     260.0
# 1017     EWR  2013      2   12    11  42.98  24.98  48.70     260.0
# 1018     EWR  2013      2   12    12  44.06  26.06  48.87     270.0
# ...

# %% [markdown]
# Now that we have all the weather from airports for feb. 12th 2013 we will take the top 5 with the windiest weather, in a result called `windiest_weather`

# %%
windiest_weather = feb_12_2013_weather.sort_values(by='wind_speed', ascending = False).head()
windiest_weather
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 1009     EWR  2013      2   12     3  39.02  26.96  61.63     260.0
# 18417    LGA  2013      2   12     2  42.98  26.06  50.94     290.0
# 1018     EWR  2013      2   12    12  44.06  26.06  48.87     270.0
# 18428    LGA  2013      2   12    13  44.06  23.00  43.02     300.0
# 18429    LGA  2013      2   12    14  44.06  23.00  43.02     300.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# 1009   1048.36058        NaN     0.0    1008.3   10.0  2013-02-12T08:00:00Z
# 18417    23.01560   31.07106     0.0    1007.1   10.0  2013-02-12T07:00:00Z
# 1018     21.86482   31.07106     0.0    1012.5   10.0  2013-02-12T17:00:00Z
# 18428    21.86482   25.31716     0.0    1011.7   10.0  2013-02-12T18:00:00Z
# 18429    20.71404   25.31716     0.0    1011.5   10.0  2013-02-12T19:00:00Z

# %% [markdown]
# Now that we have the top 5 `windiest_weather` for `feb_12_2013_weather` we can see that EWR which stands for Newark Airport, had the top wind speed for feb 12th 2013, with a wind speed of 1048. However, While EWR is a New York area airport, it is not in New York. Additionally, if 1048 mph wind speed was to be belived, it would have blown EWR off the map. So, this leads me to belive this data can not be correect, so i will go with the next result.

# %% [markdown]
# ## So for question 3. On February 12th, 2013, which New York area airport had the windiest weather?
#  I will say **LGA, Laguardia Airport, had the windiest weather*** with a recorded wind speed of 23 mph.
