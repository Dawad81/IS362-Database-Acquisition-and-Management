# %% [markdown]
# I created a .csv file to represent the data named `Alaska_and AM_West_Flights.csv` we will now import that file into a data frame

# %%
import pandas as pd

flight_data = pd.read_csv('Alaska_and AM_West_Flights.csv', index_col='Airline')

flight_data
# Out:
#                Airport  OnTime  Delayed
# Airline
# Alaska     Los Angeles     497       62
# Alaska         Phoenix     221       12
# Alaska       San Diego     212       20
# Alaska   San Francisco     503      102
# Alaska         Seattle    1841      305
# AM West    Los Angeles     694      117
# AM West        Phoenix    4840      415
# AM West      San Diego     383       65
# AM West  San Francisco     320      129
# AM West        Seattle     201       61

# %% [markdown]
# now we will neeed the precentage of delayed flights by airline at each airport. to do this we will at the `Total_Flight_Time` colume that is the sum or the `OnTime` `+` `Delayed` coulums.
# we can then use the new `Total_Flight_Time` colume to figure out the `Percentage_of_Flights_Delayed` colume by dividing the `Delayed` by the `Total_Flight_Time` colume
#  we will make the `Percentage_of_Flights_Delayed` colume easier to understand by formating it to show %

# %%
flightDataEdits = flight_data.copy()
flightDataEdits.insert(3, 'Total_Flight_Time', flight_data.OnTime + flight_data.Delayed)
flightDataEdits.insert(4, 'Percentage_of_Flights_Delayed', (flight_data.Delayed / flightDataEdits.Total_Flight_Time))
pd.options.display.float_format = '{:.2f}%'.format

flightDataEdits
# Out:
#                Airport  OnTime  Delayed  Total_Flight_Time  \
# Airline
# Alaska     Los Angeles     497       62                559
# Alaska         Phoenix     221       12                233
# Alaska       San Diego     212       20                232
# Alaska   San Francisco     503      102                605
# Alaska         Seattle    1841      305               2146
# AM West    Los Angeles     694      117                811
# AM West        Phoenix    4840      415               5255
# AM West      San Diego     383       65                448
# AM West  San Francisco     320      129                449
# AM West        Seattle     201       61                262
#
#          Percentage_of_Flights_Delayed
# Airline
# Alaska                           0.11%
# Alaska                           0.05%
# Alaska                           0.09%
# Alaska                           0.17%
# Alaska                           0.14%
# AM West                          0.14%
# AM West                          0.08%
# AM West                          0.15%
# AM West                          0.29%
# AM West                          0.23%

# %% [markdown]
# Below we can now see the percentage of delayed flights and their corissponding airports and airline

# %%
flightDataEdits[['Airport', 'Percentage_of_Flights_Delayed']]
# Out:
#                Airport  Percentage_of_Flights_Delayed
# Airline
# Alaska     Los Angeles                          0.11%
# Alaska         Phoenix                          0.05%
# Alaska       San Diego                          0.09%
# Alaska   San Francisco                          0.17%
# Alaska         Seattle                          0.14%
# AM West    Los Angeles                          0.14%
# AM West        Phoenix                          0.08%
# AM West      San Diego                          0.15%
# AM West  San Francisco                          0.29%
# AM West        Seattle                          0.23%

# %% [markdown]
# We can now begin to isolate and comepair our airlines percentage of flight delays by airports

# %%
flightDataEdits.loc[flightDataEdits['Airport']=='Phoenix']
# Out:
#          Airport  OnTime  Delayed  Total_Flight_Time  \
# Airline
# Alaska   Phoenix     221       12                233
# AM West  Phoenix    4840      415               5255
#
#          Percentage_of_Flights_Delayed
# Airline
# Alaska                           0.05%
# AM West                          0.08%

# %%
flightDataEdits.loc[flightDataEdits['Airport']=='San Diego']
# Out:
#            Airport  OnTime  Delayed  Total_Flight_Time  \
# Airline
# Alaska   San Diego     212       20                232
# AM West  San Diego     383       65                448
#
#          Percentage_of_Flights_Delayed
# Airline
# Alaska                           0.09%
# AM West                          0.15%

# %% [markdown]
# Below we can see if the Airport is not in the data frame nothing is retuned but blank values

# %%
flightDataEdits.loc[flightDataEdits['Airport']=='New York']
# Out:
# Empty DataFrame
# Columns: [Airport, OnTime, Delayed, Total_Flight_Time, Percentage_of_Flights_Delayed]
# Index: []

# %% [markdown]
# To make life a bit easier we can create a function to use to serch the data frame. we will create the `airportDelayCompare()` function to do this for us.

# %%
def airportDelayCompare(airport):
    delays = flightDataEdits.loc[flightDataEdits['Airport']== airport]
    return delays[['Airport', 'Percentage_of_Flights_Delayed']]

# %% [markdown]
# No we can just enter the Airport name as a 'string' to serch the data frame and return our results.

# %%
airportDelayCompare('Los Angeles')
# Out:
#              Airport  Percentage_of_Flights_Delayed
# Airline
# Alaska   Los Angeles                          0.11%
# AM West  Los Angeles                          0.14%

# %%
airportDelayCompare('Seattle')
# Out:
#          Airport  OnTime  Delayed  Total_Flight_Time  \
# Airline
# Alaska   Seattle    1841      305               2146
# AM West  Seattle     201       61                262
#
#          Percentage_of_Flights_Delayed
# Airline
# Alaska                           0.14%
# AM West                          0.23%

# %%
airportDelayCompare('Phoenix')
# Out:
#          Airport  OnTime  Delayed  Total_Flight_Time  \
# Airline
# Alaska   Phoenix     221       12                233
# AM West  Phoenix    4840      415               5255
#
#          Percentage_of_Flights_Delayed
# Airline
# Alaska                           0.05%
# AM West                          0.08%

# %%
flightDataEdits[['Airport', 'Percentage_of_Flights_Delayed']]
# Out:
#                Airport  Percentage_of_Flights_Delayed
# Airline
# Alaska     Los Angeles                          0.11%
# Alaska         Phoenix                          0.05%
# Alaska       San Diego                          0.09%
# Alaska   San Francisco                          0.17%
# Alaska         Seattle                          0.14%
# AM West    Los Angeles                          0.14%
# AM West        Phoenix                          0.08%
# AM West      San Diego                          0.15%
# AM West  San Francisco                          0.29%
# AM West        Seattle                          0.23%

# %%
flight_data.columns
# Out:
# Index([u'Airport', u'OnTime', u'Delayed'], dtype='object')

# %%
resetindex=flightDataEdits.copy()

# %%
resetindex
# Out:
#                Airport  OnTime  Delayed  Total_Flight_Time  \
# Airline
# Alaska     Los Angeles     497       62                559
# Alaska         Phoenix     221       12                233
# Alaska       San Diego     212       20                232
# Alaska   San Francisco     503      102                605
# Alaska         Seattle    1841      305               2146
# AM West    Los Angeles     694      117                811
# AM West        Phoenix    4840      415               5255
# AM West      San Diego     383       65                448
# AM West  San Francisco     320      129                449
# AM West        Seattle     201       61                262
#
#          Percentage_of_Flights_Delayed
# Airline
# Alaska                           0.11%
# Alaska                           0.05%
# Alaska                           0.09%
# Alaska                           0.17%
# Alaska                           0.14%
# AM West                          0.14%
# AM West                          0.08%
# AM West                          0.15%
# AM West                          0.29%
# AM West                          0.23%

# %%
resetindex.set_index('Percentage_of_Flights_Delayed', append=True)
# Out:
#                                              Airport  OnTime  Delayed  \
# Airline Percentage_of_Flights_Delayed
# Alaska  0.11%                            Los Angeles     497       62
#         0.05%                                Phoenix     221       12
#         0.09%                              San Diego     212       20
#         0.17%                          San Francisco     503      102
#         0.14%                                Seattle    1841      305
# AM West 0.14%                            Los Angeles     694      117
#         0.08%                                Phoenix    4840      415
#         0.15%                              San Diego     383       65
#         0.29%                          San Francisco     320      129
#         0.23%                                Seattle     201       61
#
#                                        Total_Flight_Time
# Airline Percentage_of_Flights_Delayed
# Alaska  0.11%                                        559
#         0.05%                                        233
#         0.09%                                        232
#         0.17%                                        605
#         0.14%                                       2146
# AM West 0.14%                                        811
#         0.08%                                       5255
#         0.15%                                        448
#         0.29%                                        449
#         0.23%                                        262

# %%
subset=resetindex.reindex(columns= ['Percentage_of_Flights_Delayed','Airport'])

# %%
subset
# Out:
#          Percentage_of_Flights_Delayed        Airport
# Airline
# Alaska                           0.11%    Los Angeles
# Alaska                           0.05%        Phoenix
# Alaska                           0.09%      San Diego
# Alaska                           0.17%  San Francisco
# Alaska                           0.14%        Seattle
# AM West                          0.14%    Los Angeles
# AM West                          0.08%        Phoenix
# AM West                          0.15%      San Diego
# AM West                          0.29%  San Francisco
# AM West                          0.23%        Seattle

# %%
subset.set_index('Percentage_of_Flights_Delayed', append=True)
# Out:
#                                              Airport
# Airline Percentage_of_Flights_Delayed
# Alaska  0.11%                            Los Angeles
#         0.05%                                Phoenix
#         0.09%                              San Diego
#         0.17%                          San Francisco
#         0.14%                                Seattle
# AM West 0.14%                            Los Angeles
#         0.08%                                Phoenix
#         0.15%                              San Diego
#         0.29%                          San Francisco
#         0.23%                                Seattle

# %%
subset['Percentage_of_Flights_Delayed'].idxmin()
# Out:
# 'Alaska'

# %%
subset['Percentage_of_Flights_Delayed'].idxmax()
# Out:
# 'AM West'

# %%
subset.set_index('Percentage_of_Flights_Delayed')

# %%
subset.xs('AM West')
# Out:
#          Percentage_of_Flights_Delayed        Airport
# Airline
# AM West                          0.14%    Los Angeles
# AM West                          0.08%        Phoenix
# AM West                          0.15%      San Diego
# AM West                          0.29%  San Francisco
# AM West                          0.23%        Seattle

# %%
subset.xs('Alaska')
# Out:
#          Percentage_of_Flights_Delayed        Airport
# Airline
# Alaska                           0.11%    Los Angeles
# Alaska                           0.05%        Phoenix
# Alaska                           0.09%      San Diego
# Alaska                           0.17%  San Francisco
# Alaska                           0.14%        Seattle
